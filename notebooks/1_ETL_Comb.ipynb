# %%
import os
import sys
import dotenv
import yaml
import pandas as pd

# Set up paths
project_dir = os.getenv('PROJECT_DIR')
dotenv_path = os.path.join(project_dir, '.env')
dotenv.load_dotenv(dotenv_path)

    
sys.path.append(project_dir)

# %%
from config import Config
from src.my_utils import fetch_table_to_parquet
from src.data.make_dataset import RawDataHandler
config = Config()

# %% [markdown]
# ---

# %%
raw_data_path = os.path.join(config.data_vault_dir, 'Intel_Image_CNN')

handle_raw_data = RawDataHandler(raw_data_path)
df = handle_raw_data.fetch_raw_data()
df = handle_raw_data.encode_labels()

# %%
df
# Out:
#          Segment   Category  \
# 0      seg_train  buildings
# 1      seg_train  buildings
# 2      seg_train  buildings
# 3      seg_train  buildings
# 4      seg_train  buildings
# ...          ...        ...
# 24330   seg_pred   seg_pred
# 24331   seg_pred   seg_pred
# 24332   seg_pred   seg_pred
# 24333   seg_pred   seg_pred
# 24334   seg_pred   seg_pred
#
#                                                     Path  Label
# 0      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 1      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 2      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 3      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 4      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# ...                                                  ...    ...
# 24330  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24331  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24332  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24333  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24334  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
#
# [24335 rows x 4 columns]

# %% [markdown]
# ---

# %%
# # Create the SQLAlchemy engine and store the DataFrame into PostgreSQL database
# engine = create_engine(db_url)

# df.to_sql(
#     'intel_image_data',
#     engine,
#     if_exists='replace',
#     index=False
#     )

# %%
df = fetch_table_to_parquet(
    db_url=config.db_url,
    table_name='intel_image_data',
    data_dir=config.data_dir,
    parquet_file_name='intel_image_paths_labels.parq',
    save_as_excel=True,
    excel_file_name='intel_image_paths_labels.xlsx',
    return_metadata=False
    )
df
# Out:
# Files saved to: data/raw/[file_name]
#          Segment   Category  \
# 0      seg_train  buildings
# 1      seg_train  buildings
# 2      seg_train  buildings
# 3      seg_train  buildings
# 4      seg_train  buildings
# ...          ...        ...
# 24330   seg_pred   seg_pred
# 24331   seg_pred   seg_pred
# 24332   seg_pred   seg_pred
# 24333   seg_pred   seg_pred
# 24334   seg_pred   seg_pred
#
#                                                     Path  Label
# 0      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 1      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 2      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 3      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 4      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# ...                                                  ...    ...
# 24330  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24331  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24332  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24333  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24334  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
#
# [24335 rows x 4 columns]

# %% [markdown]
# ---

# %%
raw_data_path_parq = os.path.join(config.data_dir, 'raw/intel_image_paths_labels.parq')
raw_data_path_xlsx = os.path.join(config.data_dir, 'raw/intel_image_paths_labels.xlsx')

# %%
pd.read_parquet(raw_data_path_parq, engine='pyarrow')
# Out:
#          Segment   Category  \
# 0      seg_train  buildings
# 1      seg_train  buildings
# 2      seg_train  buildings
# 3      seg_train  buildings
# 4      seg_train  buildings
# ...          ...        ...
# 24330   seg_pred   seg_pred
# 24331   seg_pred   seg_pred
# 24332   seg_pred   seg_pred
# 24333   seg_pred   seg_pred
# 24334   seg_pred   seg_pred
#
#                                                     Path  Label
# 0      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 1      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 2      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 3      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 4      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# ...                                                  ...    ...
# 24330  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24331  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24332  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24333  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24334  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
#
# [24335 rows x 4 columns]

# %%
pd.read_excel(raw_data_path_xlsx)
# Out:
#          Segment   Category  \
# 0      seg_train  buildings
# 1      seg_train  buildings
# 2      seg_train  buildings
# 3      seg_train  buildings
# 4      seg_train  buildings
# ...          ...        ...
# 24330   seg_pred   seg_pred
# 24331   seg_pred   seg_pred
# 24332   seg_pred   seg_pred
# 24333   seg_pred   seg_pred
# 24334   seg_pred   seg_pred
#
#                                                     Path  Label
# 0      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 1      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 2      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 3      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# 4      C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    5.0
# ...                                                  ...    ...
# 24330  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24331  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24332  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24333  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
# 24334  C:\Users\delst\Data_Vault\Intel_Image_CNN\seg_...    NaN
#
# [24335 rows x 4 columns]
